# %% [markdown]
# <a href="https://colab.research.google.com/github/jgoncsilva/Classes_IronHack/blob/master/sql_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# how to connect sql to python and how to use python to help you

# you may need to install pip install mysql-connector

import mysql.connector

# %%
# establishing a connection to a database -> a group of schemas


# establish a connection with the schema you want to talk to

# perform simple queries with pyhon

# %%
# open the door between python and my databases ->  I specified Sakila

cnx = mysql.connector.connect(user = 'root',password = 'root', host ='localhost', database = 'sakila')

# %%
# check if the connection was successful

cnx.is_connected()
# Out:
# True

# %%
# good practice -> a try , except would be better

if cnx.is_connected():
    print("Connection open")
    # do stuff you need to the database
else:
    print("Connection is not successfully open")
# Out:
# Connection open

# %%
# we need to define the object we will use to interact with the database

cursor = cnx.cursor()

# %%
# now we want to create a query
# so we still write our code in SQL but then execute it through python to get the output as a python object

query = ("SELECT * FROM sakila.actor;")

# %%
# execute the query -> we need to call the cursor to execute our query
cursor.execute(query)

# %%
# this cursos currently holds the results of that query

results = cursor.fetchall()

# %%
results
# Out:
# [(1, 'PENELOPE', 'GUINESS', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (2, 'NICK', 'WAHLBERG', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (3, 'ED', 'CHASE', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (4, 'JENNIFER', 'DAVIS', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (5, 'JOHNNY', 'LOLLOBRIGIDA', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (6, 'BETTE', 'NICHOLSON', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (7, 'GRACE', 'MOSTEL', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (8, 'MATTHEW', 'JOHANSSON', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (9, 'JOE', 'SWANK', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (10, 'CHRISTIAN', 'GABLE', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (11, 'ZERO', 'CAGE', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (12, 'KARL', 'BERRY', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (13, 'UMA', 'WOOD', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (14, 'VIVIEN', 'BERGEN', datetime.datetime(2006, 2, 15, 4, 34, 33)),
# ...

# %%
# its a usual python object -> this is our usual playground
for element in results:
    print(element)
# Out:
# (1, 'PENELOPE', 'GUINESS', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (2, 'NICK', 'WAHLBERG', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (3, 'ED', 'CHASE', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (4, 'JENNIFER', 'DAVIS', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (5, 'JOHNNY', 'LOLLOBRIGIDA', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (6, 'BETTE', 'NICHOLSON', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (7, 'GRACE', 'MOSTEL', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (8, 'MATTHEW', 'JOHANSSON', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (9, 'JOE', 'SWANK', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (10, 'CHRISTIAN', 'GABLE', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (11, 'ZERO', 'CAGE', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (12, 'KARL', 'BERRY', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (13, 'UMA', 'WOOD', datetime.datetime(2006, 2, 15, 4, 34, 33))
# (14, 'VIVIEN', 'BERGEN', datetime.datetime(2006, 2, 15, 4, 34, 33))
# ...

# %%
import pandas as pd

actors_df = pd.DataFrame(results)

# %%
actors_df["full name"] = actors_df[1] + " " +  actors_df[2] 
actors_df
# Out:
#        0          1             2                   3            full name
# 0      1   PENELOPE       GUINESS 2006-02-15 04:34:33     PENELOPE GUINESS
# 1      2       NICK      WAHLBERG 2006-02-15 04:34:33        NICK WAHLBERG
# 2      3         ED         CHASE 2006-02-15 04:34:33             ED CHASE
# 3      4   JENNIFER         DAVIS 2006-02-15 04:34:33       JENNIFER DAVIS
# 4      5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33  JOHNNY LOLLOBRIGIDA
# 5      6      BETTE     NICHOLSON 2006-02-15 04:34:33      BETTE NICHOLSON
# 6      7      GRACE        MOSTEL 2006-02-15 04:34:33         GRACE MOSTEL
# 7      8    MATTHEW     JOHANSSON 2006-02-15 04:34:33    MATTHEW JOHANSSON
# 8      9        JOE         SWANK 2006-02-15 04:34:33            JOE SWANK
# 9     10  CHRISTIAN         GABLE 2006-02-15 04:34:33      CHRISTIAN GABLE
# 10    11       ZERO          CAGE 2006-02-15 04:34:33            ZERO CAGE
# ...

# %%
X = input("please enter your default email")

query = ("CREATE TABLE IF NOT EXISTS"
"labs.demo("
"student_id INT PRIMARY KEY,"
"student_name VARCHAR(52),"
"email VARCHAR(32) DEFAULT" +  x + ',"
"coolness INT NOT NULL)")

# %%
for row in actor_df:
    query = "INSERT INTO labs.students(student_id, student_name, coolness)"
             + "VALUES ("row[id], "Jose Pereira",  10);"

# %%
cursor.execute(query)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     471                                raw=raw, buffered=buffered,
# --> 472                                raw_as_string=raw_as_string)
#     473         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'EXISTSlabs.demo(student_id INT PRIMARY KEY,student_name VARCHAR(52),email VARCHA' at line 1
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-66-70f19cd38195> in <module>()
# ----> 1 cursor.execute(query)
#
# ...

# %%
# once you have connected to sql and done everything

# saving any changes you did on the database
cnx.commit()
# clear the cursor
cursor.close()

# closes the door between python and SQL
cnx.close()

# %%
# to solve problems 
cnx = mysql.connector.connect(user = 'root', password = 'root', host ='localhost', database = 'sakila', auth_plugin='mysql_native_password')

cnx.is_connected()
# Out:
# True

# %% [markdown]
# https://miro.medium.com/max/2428/1*9TZHTGKjIyUOAvmQkV1RNA.png
